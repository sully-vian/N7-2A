# %% [markdown]
# <center>
# <h1> TP-Projet d'optimisation numérique </h1>
# <h1> Algorithme de Newton </h1>
# </center>

# %% [markdown]
# ## Implémentation
#
# 1. Coder l’algorithme de Newton dans le fichier `src/newton.jl` en respectant la spécification donnée dans ce même fichier ;
# 2. Exécuter les tests ci-dessous et vérifier qu'ils passent.
#
# Pour les tests, nous avons défini les fonctions suivantes $f_1 \colon \mathbb{R}^3 \to \mathbb{R}$
# et $f_2 \colon \mathbb{R}^2 \to \mathbb{R}$.
#
# $$
#     f_{1}(x_1, x_2, x_3) = 2 (x_1 +x_2 + x_3 -3)^2 + (x_1-x_2)^2 + (x_2 - x_3)^2
# $$
# et
# $$
#     f_{2}(x_1,x_2) = 100(x_2-x_1^2)^2 + (1-x_1)^2.
# $$
#
# **Remarque.** On peut retrouver ces fonctions dans le fichier `test/fonctions_de_tests.jl`.

# %%
include("../src/newton.jl")         # votre algorithme de Newton
include("../test/tester_newton.jl") # la fonction pour tester votre algorithme de Newton

#
afficher = false # si true, alors affiche les résultats des algorithmes

#
tester_newton(newton, afficher); # tester l'algorithme de Newton
# Out:
# Affichage des résultats des algorithmes : false
#
# test f2 : x0 = x023: Error During Test at /home/vhy9665/Desktop/N7-2A/OptiNum/test/tester_newton.jl:113
#   Got exception outside of a @test
#   SingularException(2)
#   Stacktrace:
#     [1] checknonsingular
#       @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/LinearAlgebra/src/factorization.jl:19 [inlined]
#     [2] checknonsingular
#       @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/LinearAlgebra/src/factorization.jl:21 [inlined]
#     [3] #lu!#170
#       @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/LinearAlgebra/src/lu.jl:82 [inlined]
#     [4] #lu#177
#       @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/LinearAlgebra/src/lu.jl:279 [inlined]
#     [5] lu (repeats 2 times)
#       @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/LinearAlgebra/src/lu.jl:278 [inlined]
#     [6] \(A::Matrix{Float64}, B::Vector{Float64})
#       @ LinearAlgebra /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/LinearAlgebra/src/generic.jl:1110
#     [7] newton(f::typeof(fct2), gradf::typeof(grad_fct2), hessf::typeof(hess_fct2), x0::Vector{Float64}; max_iter::Int64, tol_abs::Float64, tol_rel::Float64, epsilon::Float64)
#       @ Main ~/Desktop/N7-2A/OptiNum/src/newton.jl:62
#     [8] macro expansion
#       @ ~/Desktop/N7-2A/OptiNum/test/tester_newton.jl:114 [inlined]
#     [9] macro expansion
#       @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#    [10] macro expansion
#       @ ~/Desktop/N7-2A/OptiNum/test/tester_newton.jl:114 [inlined]
#    [11] macro expansion
#       @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#    [12] tester_newton(newton::typeof(newton), afficher::Bool)
#       @ Main ~/Desktop/N7-2A/OptiNum/test/tester_newton.jl:33
#    [13] top-level scope
#       @ In[13]:8
#    [14] eval
#       @ ./boot.jl:368 [inlined]
#    [15] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#       @ Base ./loading.jl:1428
#    [16] softscope_include_string(m::Module, code::String, filename::String)
#       @ SoftGlobalScope /mnt/n7fs/ens/tp_cots/.julia/packages/SoftGlobalScope/u4UzH/src/SoftGlobalScope.jl:65
#    [17] execute_request(socket::ZMQ.Socket, msg::IJulia.Msg)
#       @ IJulia /mnt/n7fs/ens/tp_cots/.julia/packages/IJulia/6TIq1/src/execute_request.jl:67
#    [18] #invokelatest#2
#       @ ./essentials.jl:729 [inlined]
#    [19] invokelatest
#       @ ./essentials.jl:726 [inlined]
#    [20] eventloop(socket::ZMQ.Socket)
#       @ IJulia /mnt/n7fs/ens/tp_cots/.julia/packages/IJulia/6TIq1/src/eventloop.jl:8
#    [21] (::IJulia.var"#15#18")()
#       @ IJulia ./task.jl:484
# Test Summary:             | Pass  Error  Total  Time
# algorithme de Newton      |   15      1     16  0.4s
#   test f1 : x0 = solution |    3             3  0.2s
#   test f1 : x0 = x011     |    3             3  0.0s
#   test f1 : x0 = x012     |    3             3  0.1s
#   test f2 : x0 = x021     |    3             3  0.0s
#   test f2 : x0 = x022     |    3             3  0.1s
#   test f2 : x0 = x023     |           1      1  0.0s
# Some tests did not pass: 15 passed, 0 failed, 1 errored, 0 broken.
#
# Stacktrace:
#  [1] finish(ts::Test.DefaultTestSet)
#    @ Test /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1092
#  [2] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1368 [inlined]
#  [3] tester_newton(newton::typeof(newton), afficher::Bool)
#    @ Main ~/Desktop/N7-2A/OptiNum/test/tester_newton.jl:33
#  [4] top-level scope
#    @ In[13]:8

# %%
include("../src/newton.jl") # votre algorithme de Newton
include("../test/fonctions_de_tests.jl") # pour avoir la fonction d'affichage des résultats

# Fonction f0
# -----------
f0(x)      =  sin(x)
grad_f0(x) =  cos(x) # la gradient de la fonction f0
hess_f0(x) = -sin(x) # la hessienne de la fonction f0
solution   = -pi/2

x0 = solution
x_sol, f_sol, flag, nb_iters = newton(f0, grad_f0, hess_f0, x0)
afficher_resultats("Newton", "f0", x0, x_sol, f_sol, flag, nb_iters, solution)

x0 = -pi/2+0.5
x_sol, f_sol, flag, nb_iters = newton(f0, grad_f0, hess_f0, x0)
afficher_resultats("Newton", "f0", x0, x_sol, f_sol, flag, nb_iters, solution)

x0 = pi/2
x_sol, f_sol, flag, nb_iters = newton(f0, grad_f0, hess_f0, x0)
afficher_resultats("Newton", "f0", x0, x_sol, f_sol, flag, nb_iters, solution)
# Out:
# -------------------------------------------------------------------------
# Résultats de : Newton appliqué à f0:
#   * x0       = -1.5707963267948966
#   * x_sol    = -1.5707963267948966
#   * f(x_sol) = -1.0
#   * nb_iters = 1
#   * flag     = 0
#   * solution = -1.5707963267948966
# -------------------------------------------------------------------------
# Résultats de : Newton appliqué à f0:
#   * x0       = -1.0707963267948966
#   * x_sol    = -1.5707963267949088
#   * f(x_sol) = -1.0
#   * nb_iters = 3
#   * flag     = 0
#   * solution = -1.5707963267948966
# -------------------------------------------------------------------------
# Résultats de : Newton appliqué à f0:
#   * x0       = 1.5707963267948966
#   * x_sol    = 1.5707963267948966
#   * f(x_sol) = 1.0
#   * nb_iters = 1
#   * flag     = 0
#   * solution = -1.5707963267948966

# %% [markdown]
# ## Interprétation
#
# 1. Justifier les résultats obtenus pour l'exemple $f_0$ ci-dessus;
# 2. Justifier que l’algorithme implémenté converge en une itération pour $f_{1}$;
# 3. Justifier que l’algorithme puisse ne pas converger pour $f_{2}$ avec certains points initiaux.
#
# **Remarque.** Vous pouvez mettre `affiche=true` dans les tests de l'algorithme de Newton pour
# vous aider.
